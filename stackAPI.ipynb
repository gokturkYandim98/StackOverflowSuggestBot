# %%
# !pip install stackapi
# Out:
# ...
#   Created wheel for stackapi: filename=StackAPI-0.2.0-py3-none-any.whl size=5858 sha256=89061f47ee6d4f429c3af7fc22dd5a8511e5d703f7857a23df14e19bcf5dcb7a
#   Stored in directory: /root/.cache/pip/wheels/ec/db/60/df42a65853e3581c26a2fbb2012a228cb8e267369a3b9ca44d
# Successfully built stackapi
# ...

# %%
from stackapi import StackAPI

SITE = StackAPI('stackoverflow')
SITE.max_pages=10
SITE.page_size=10
SITE.key='YqYacsm9i5b2gxBbdsQUxg(('
questions = SITE.fetch('questions',order='desc',tagged='python',site='stackoverflow')

print(len(questions['items']))

for quest in questions['items']:
    if 'title' not in quest or quest['is_answered'] == False:
        continue
    title = quest['title'] 
    print('Question :- {0}'.format(title))
    question_id = quest['question_id']
    print('Question ID :- {0}'.format(question_id))
    top_answer = SITE.fetch('questions/' + str(question_id) + '/answers', order = 'desc', sort='votes')
    if 'accepted_answer_id' in quest.keys():
      accepted_answer_id = quest['accepted_answer_id']
      print('Accepted Answer ID :- {0}'.format(accepted_answer_id))
    print("\n----------------------------------------------------------------\n")
# Out:
# 100
# Question :- Check if two contours intersect?
# Question ID :- 55641425
# Accepted Answer ID :- 55642365
#
# ----------------------------------------------------------------
#
# Question :- How to plot zebra style axis in matplotlib
# Question ID :- 57313303
# Accepted Answer ID :- 71945963
#
# ----------------------------------------------------------------
#
# Question :- Using git submodules with python
# Question ID :- 64988110
#
# ----------------------------------------------------------------
#
# Question :- How to get reticulate to access virtual environment
# Question ID :- 59715101
#
# ----------------------------------------------------------------
#
# Question :- Is there a way to make sure formatted string is always in quotations?
# Question ID :- 71960952
# Accepted Answer ID :- 71961412
#
# ----------------------------------------------------------------
#
# ...

# %%
import requests
import json

# %%
api_key='YqYacsm9i5b2gxBbdsQUxg(('
request_statement = "https://api.stackexchange.com/2.3/tags/python/faq?site=stackoverflow&key="+api_key
r = requests.get(request_statement)

# %%
r.text
# Out:
# '{"items":[{"tags":["python","pandas"],"owner":{"account_id":510111,"reputation":54282,"user_id":1222578,"user_type":"registered","accept_rate":100,"profile_image":"https://www.gravatar.com/avatar/daae63146dbed42f50cd56f7268c6260?s=256&d=identicon&r=PG","display_name":"Marius","link":"https://stackoverflow.com/users/1222578/marius"},"is_answered":true,"view_count":40599,"accepted_answer_id":20159305,"answer_count":5,"score":220,"locked_date":1543143021,"last_activity_date":1649006979,"creation_date":1384990299,"last_edit_date":1495540498,"question_id":20109391,"content_license":"CC BY-SA 3.0","link":"https://stackoverflow.com/questions/20109391/how-to-make-good-reproducible-pandas-examples","title":"How to make good reproducible pandas examples"},{"tags":["python","if-statement","comparison","match","boolean-logic"],"owner":{"account_id":2112437,"reputation":8061,"user_id":1877442,"user_type":"registered","profile_image":"https://www.gravatar.com/avatar/d13a4b93913722793496a3123de88a
# ...

# %%
 resp=json.loads(r.text)

# %%
resp
# Out:
# {'has_more': True,
#  'items': [{'accepted_answer_id': 20159305,
#    'answer_count': 5,
#    'content_license': 'CC BY-SA 3.0',
#    'creation_date': 1384990299,
#    'is_answered': True,
#    'last_activity_date': 1649006979,
#    'last_edit_date': 1495540498,
#    'link': 'https://stackoverflow.com/questions/20109391/how-to-make-good-reproducible-pandas-examples',
#    'locked_date': 1543143021,
#    'owner': {'accept_rate': 100,
#     'account_id': 510111,
#     'display_name': 'Marius',
#     'link': 'https://stackoverflow.com/users/1222578/marius',
#     'profile_image': 'https://www.gravatar.com/avatar/daae63146dbed42f50cd56f7268c6260?s=256&d=identicon&r=PG',
#     'reputation': 54282,
#     'user_id': 1222578,
#     'user_type': 'registered'},
#    'question_id': 20109391,
#    'score': 220,
#    'tags': ['python', 'pandas'],
#    'title': 'How to make good reproducible pandas examples',
#    'view_count': 40599},
#   {'accepted_answer_id': 15112149,
#    'answer_count': 28,
# ...
