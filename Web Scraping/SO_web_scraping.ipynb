# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
def href(soup):
  # get all href links from one page 
  href=[]
  # print(len(soup.find_all("a",class_="question-hyperlink",href=True)))
  for i in soup.find_all("a",class_="question-hyperlink",href=True):
    href.append(i['href'])
  return href

# %%
def clean_empty_hrefs(hrefs):
   # remove all empty lists
    list_hrefs=[]
    for i in hrefs:
        if i!=[]:
            list_hrefs.append(i)
    # merge all elemenets in one list
    herfs_list=[]
    for i in list_hrefs:
        for j in i:
            herfs_list.append(j)
    return herfs_list

# %%
def add_prefix(herfs_list):
    # rearrage those links who do not have 'https://stackoverflow.com' prefix    
    new_href=[]
    prefix='https://stackoverflow.com'
    for h in herfs_list:
        if 'https' not in h and 'stackexchange' not in h:
            m=prefix+h+"answertab=votes#tab-top"
            new_href.append(m)
        else:
            new_href.append(h+"answertab=votes#tab-top")
    return new_href

# %%
def single_page_scraper(url):
    req=requests.get(url=url)
    soup=BeautifulSoup(req.text,"html.parser")
    return soup
def single_page_question_answer(url):
    page=single_page_scraper(url).find_all("div",class_="post-text",itemprop="text")
    question=[i.find("p").get_text()for i in page][0]
    answer=[i.find("p").get_text() for i in page][1:3]
    
    return question,answer

# %%
import itertools
def questions_answers(start_page,end_page):
    soups=[]
    for page in range(start_page,end_page):
        req=requests.get(url='https://stackoverflow.com/questions/tagged/python?tab=votes&page={}&pagesize=15'.format(page))
        soup=BeautifulSoup(req.text,"html.parser")
        soups.append(soup)
    print("Soups: ",len(soups))
    print("Soups are ready!")
    # obtain all href
    hrefs=[]
    for soup in soups:
        hrefs.append(href(soup))
    hrefs_list=clean_empty_hrefs(hrefs)
    print("Hrefs",len(hrefs_list))
    new_hrefs_list=add_prefix(hrefs_list)
    print("New hrefs:",len(new_hrefs_list))
    print("All hrefs are ready!")
    questions=[]
    answers=[]
    for url in new_hrefs_list:
      print(url)
      try:
          q,a=single_page_question_answer(url)
          print(q,a)
          questions.append(q)
          answers.append(a)
      except:
          pass
    print("quesitons and answers are ready!")
    print("Questions:",len(questions))
    print("Answers:", len(answers))
    
    new_answers=[]
    for i in range(len(answers)):
        try:
            new_answers.append(answers[i][0])
        except:
            new_answers.append(None)
    print("All most done!")
    new_q = []
    new_a = []
    merge_answer=list(itertools.chain.from_iterable(answers))
    #print(merge_answer)
    for i in range(len(merge_answer) - 1):
        new_q.append(merge_answer[i])
        new_a.append(merge_answer[i+1])
    print("New Answers:",len(new_answers))
    print("Merge Answers:",len(merge_answer))
    print("newq:",len(new_q))
    print("new_a:",len(new_a))
            
    return questions+new_q, new_answers+new_a

# %%
Questions,Answers=questions_answers(1,20)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# https://stackoverflow.com/users/24039/simonanswertab=votes#tab-top
# https://stackoverflow.com/users/24039/simonanswertab=votes#tab-top
# https://stackoverflow.com/questions/176918/finding-the-index-of-an-item-in-a-listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/indexinganswertab=votes#tab-top
# https://stackoverflow.com/users/25680/eugene-manswertab=votes#tab-top
# https://stackoverflow.com/users/25680/eugene-manswertab=votes#tab-top
# https://stackoverflow.com/questions/3294889/iterating-over-dictionaries-using-for-loopsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/users/1212392/topchefanswertab=votes#tab-top
# https://stackoverflow.com/users/1212392/topchefanswertab=votes#tab-top
# https://stackoverflow.com/questions/423379/using-global-variables-in-a-functionanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/global-variablesanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/scopeanswertab=votes#tab-top
# https://stackoverflow.com/users/46646/user46646answertab=votes#tab-top
# https://stackoverflow.com/users/46646/user46646answertab=votes#tab-top
# https://stackoverflow.com/questions/3437059/does-python-have-a-string-contains-substring-methodanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/substringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/containsanswertab=votes#tab-top
# https://stackoverflow.com/users/39677/blankmananswertab=votes#tab-top
# https://stackoverflow.com/users/39677/blankmananswertab=votes#tab-top
# https://stackoverflow.com/questions/415511/how-do-i-get-the-current-timeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/datetimeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/timeanswertab=votes#tab-top
# https://stackoverflow.com/users/46646/user46646answertab=votes#tab-top
# https://stackoverflow.com/users/46646/user46646answertab=votes#tab-top
# https://stackoverflow.com/questions/3207219/how-do-i-list-all-files-of-a-directoryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/directoryanswertab=votes#tab-top
# https://stackoverflow.com/users/385652/duhhunjonnanswertab=votes#tab-top
# https://stackoverflow.com/users/385652/duhhunjonnanswertab=votes#tab-top
# https://stackoverflow.com/questions/6470428/catch-multiple-exceptions-in-one-line-except-blockanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/exceptionanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/exception-handlinganswertab=votes#tab-top
# https://stackoverflow.com/users/198633/inspectorg4dgetanswertab=votes#tab-top
# https://stackoverflow.com/users/198633/inspectorg4dgetanswertab=votes#tab-top
# https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-valueanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/sortinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/users/2786/gern-blanstonanswertab=votes#tab-top
# https://stackoverflow.com/users/2786/gern-blanstonanswertab=votes#tab-top
# https://stackoverflow.com/questions/1436703/what-is-the-difference-between-str-and-repranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/magic-methodsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/repranswertab=votes#tab-top
# https://stackoverflow.com/users/165495/casebashanswertab=votes#tab-top
# https://stackoverflow.com/users/165495/casebashanswertab=votes#tab-top
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dataframeanswertab=votes#tab-top
# https://stackoverflow.com/users/245549/romananswertab=votes#tab-top
# https://stackoverflow.com/users/245549/romananswertab=votes#tab-top
# https://stackoverflow.com/questions/1024847/how-can-i-add-new-keys-to-a-dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/lookupanswertab=votes#tab-top
# https://stackoverflow.com/users/90777/lfaraoneanswertab=votes#tab-top
# https://stackoverflow.com/users/90777/lfaraoneanswertab=votes#tab-top
# https://stackoverflow.com/questions/123198/how-to-copy-filesanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/fileanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/copyanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/filesystemsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/file-copyinganswertab=votes#tab-top
# https://stackoverflow.com/users/17693/mattanswertab=votes#tab-top
# https://stackoverflow.com/users/17693/mattanswertab=votes#tab-top
# https://stackoverflow.com/questions/606191/convert-bytes-to-a-stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python-3.xanswertab=votes#tab-top
# https://stackoverflow.com/users/2239/tomas-sedovicanswertab=votes#tab-top
# https://stackoverflow.com/users/2239/tomas-sedovicanswertab=votes#tab-top
# https://stackoverflow.com/questions/1720421/how-do-i-concatenate-two-lists-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/concatenationanswertab=votes#tab-top
# https://stackoverflow.com/users/206504/y2kanswertab=votes#tab-top
# https://stackoverflow.com/users/206504/y2kanswertab=votes#tab-top
# https://stackoverflow.com/questions/53513/how-do-i-check-if-a-list-is-emptyanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/users/4872/rayanswertab=votes#tab-top
# https://stackoverflow.com/users/4872/rayanswertab=votes#tab-top
# https://stackoverflow.com/questions/448271/what-is-init-py-foranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/moduleanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/packageanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python-packaginganswertab=votes#tab-top
# https://stackoverflow.com/users/42974/matanswertab=votes#tab-top
# https://stackoverflow.com/users/42974/matanswertab=votes#tab-top
# https://stackoverflow.com/questions/252703/what-is-the-difference-between-pythons-list-methods-append-and-extendanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/data-structuresanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/appendanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/extendanswertab=votes#tab-top
# https://stackoverflow.com/users/15055/claudiuanswertab=votes#tab-top
# https://stackoverflow.com/users/15055/claudiuanswertab=votes#tab-top
# https://stackoverflow.com/questions/1132941/least-astonishment-and-the-mutable-default-argumentanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/language-designanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/default-parametersanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/least-astonishmentanswertab=votes#tab-top
# https://stackoverflow.com/users/78374/stefano-borinianswertab=votes#tab-top
# https://stackoverflow.com/users/78374/stefano-borinianswertab=votes#tab-top
# https://stackoverflow.com/questions/510348/how-can-i-make-a-time-delay-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python-3.xanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/delayanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/sleepanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/timedelayanswertab=votes#tab-top
# https://stackoverflow.com/users/46646/user46646answertab=votes#tab-top
# https://stackoverflow.com/users/46646/user46646answertab=votes#tab-top
# https://stackoverflow.com/questions/986006/how-do-i-pass-a-variable-by-referenceanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/referenceanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/parameter-passinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pass-by-referenceanswertab=votes#tab-top
# https://stackoverflow.com/users/259/david-sykesanswertab=votes#tab-top
# https://stackoverflow.com/users/259/david-sykesanswertab=votes#tab-top
# https://stackoverflow.com/questions/2612802/how-do-i-clone-a-list-so-that-it-doesnt-change-unexpectedly-after-assignmentanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/referenceanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/copyanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/cloneanswertab=votes#tab-top
# https://stackoverflow.com/users/187730/afanswertab=votes#tab-top
# https://stackoverflow.com/users/187730/afanswertab=votes#tab-top
# https://stackoverflow.com/questions/739654/how-to-make-function-decorators-and-chain-them-togetheranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/decoratoranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python-decoratorsanswertab=votes#tab-top
# https://stackoverflow.com/users/1897/imrananswertab=votes#tab-top
# https://stackoverflow.com/users/1897/imrananswertab=votes#tab-top
# https://stackoverflow.com/questions/576169/understanding-python-super-with-init-methodsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/classanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/oopanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/inheritanceanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/superanswertab=votes#tab-top
# https://stackoverflow.com/users/56763/mizipzoranswertab=votes#tab-top
# https://stackoverflow.com/users/56763/mizipzoranswertab=votes#tab-top
# https://stackoverflow.com/questions/17071871/how-do-i-select-rows-from-a-dataframe-based-on-column-valuesanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dataframeanswertab=votes#tab-top
# https://stackoverflow.com/users/458429/szlianswertab=votes#tab-top
# https://stackoverflow.com/users/458429/szlianswertab=votes#tab-top
# https://stackoverflow.com/questions/36901/what-does-double-star-asterisk-and-star-asterisk-do-for-parametersanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/syntaxanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/parameter-passinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/variadic-functionsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/argument-unpackinganswertab=votes#tab-top
# https://stackoverflow.com/users/2572/toddanswertab=votes#tab-top
# https://stackoverflow.com/users/2572/toddanswertab=votes#tab-top
# https://stackoverflow.com/questions/6996603/how-do-i-delete-a-file-or-folder-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/file-ioanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/directoryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/delete-fileanswertab=votes#tab-top
# https://stackoverflow.com/users/854002/zygimantasanswertab=votes#tab-top
# https://stackoverflow.com/users/854002/zygimantasanswertab=votes#tab-top
# https://stackoverflow.com/questions/2052390/manually-raising-throwing-an-exception-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/exceptionanswertab=votes#tab-top
# https://stackoverflow.com/users/179736/timexanswertab=votes#tab-top
# https://stackoverflow.com/users/179736/timexanswertab=votes#tab-top
# https://stackoverflow.com/questions/332289/how-do-you-change-the-size-of-figures-drawn-with-matplotlibanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/graphanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/matplotlibanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/plotanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/visualizationanswertab=votes#tab-top
# https://stackoverflow.com/users/40849/tatwrightanswertab=votes#tab-top
# https://stackoverflow.com/users/40849/tatwrightanswertab=votes#tab-top
# https://stackoverflow.com/questions/312443/how-do-you-split-a-list-into-evenly-sized-chunksanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/splitanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/chunksanswertab=votes#tab-top
# https://stackoverflow.com/users/112415/jespernanswertab=votes#tab-top
# https://stackoverflow.com/users/112415/jespernanswertab=votes#tab-top
# https://stackoverflow.com/questions/287871/how-do-i-print-colored-text-to-the-terminal-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/terminalanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/outputanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/ansi-colorsanswertab=votes#tab-top
# https://stackoverflow.com/users/35062/abosamooranswertab=votes#tab-top
# https://stackoverflow.com/users/35062/abosamooranswertab=votes#tab-top
# https://stackoverflow.com/questions/466345/converting-string-into-datetimeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/datetimeanswertab=votes#tab-top
# https://stackoverflow.com/users/12870/olianswertab=votes#tab-top
# https://stackoverflow.com/users/12870/olianswertab=votes#tab-top
# https://stackoverflow.com/questions/4906977/how-do-i-access-environment-variables-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/environment-variablesanswertab=votes#tab-top
# https://stackoverflow.com/users/601738/amit-yadavanswertab=votes#tab-top
# https://stackoverflow.com/users/601738/amit-yadavanswertab=votes#tab-top
# https://stackoverflow.com/questions/5137497/find-the-current-directory-and-files-directoryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/directoryanswertab=votes#tab-top
# https://stackoverflow.com/users/374797/john-howardanswertab=votes#tab-top
# https://stackoverflow.com/users/374797/john-howardanswertab=votes#tab-top
# https://stackoverflow.com/questions/1602934/check-if-a-given-key-already-exists-in-a-dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/users/112850/mohan-gulatianswertab=votes#tab-top
# https://stackoverflow.com/users/112850/mohan-gulatianswertab=votes#tab-top
# https://stackoverflow.com/questions/4750806/how-can-i-install-pip-on-windowsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/windowsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/installationanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pipanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/easy-installanswertab=votes#tab-top
# https://stackoverflow.com/posts/4750806/revisionsanswertab=votes#tab-top
# https://stackoverflow.com/users/362951answertab=votes#tab-top
# https://stackoverflow.com/questions/30081275/why-is-1000000000000000-in-range1000000000000001-so-fast-in-python-3answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/performanceanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python-3.xanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/rangeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python-internalsanswertab=votes#tab-top
# https://stackoverflow.com/users/2437514/rick-supports-monicaanswertab=votes#tab-top
# https://stackoverflow.com/users/2437514/rick-supports-monicaanswertab=votes#tab-top
# https://stackoverflow.com/questions/379906/how-do-i-parse-a-string-to-a-float-or-intanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/parsinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/floating-pointanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/type-conversionanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/integeranswertab=votes#tab-top
# https://stackoverflow.com/users/30529/tristan-havelickanswertab=votes#tab-top
# https://stackoverflow.com/users/30529/tristan-havelickanswertab=votes#tab-top
# https://stackoverflow.com/questions/930397/how-do-i-get-the-last-element-of-a-listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/indexinganswertab=votes#tab-top
# https://stackoverflow.com/users/114066/januszanswertab=votes#tab-top
# https://stackoverflow.com/users/114066/januszanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=2answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=3answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=4answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=5answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=38469answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=2answertab=votes#tab-top
# https://stackoverflow.blog/2022/04/04/comparing-go-vs-c-in-embedded-applications/answertab=votes#tab-top
# https://stackoverflow.blog/2022/03/31/time-to-get-on-trend-filters/answertab=votes#tab-top
# https://meta.stackoverflow.com/questions/416964/the-future-of-our-jobs-ad-slotsanswertab=votes#tab-top
# https://meta.stackoverflow.com/questions/416735/ask-wizard-for-new-users-feature-test-is-now-liveanswertab=votes#tab-top
# https://meta.stackoverflow.com/questions/416887/calling-up-moderators-from-the-2021-election-welcome-dharman-ryan-manswertab=votes#tab-top
# https://meta.stackoverflow.com/questions/416851/staging-ground-workflow-question-details-actionsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+python-3.xanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+djangoanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+numpyanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+dataframeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+python-2.7answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+matplotlibanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+tensorflowanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+tkinteranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+flaskanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+regexanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+seleniumanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+arraysanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+csvanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+jsonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+htmlanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+beautifulsoupanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+kerasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+opencvanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+web-scrapinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+machine-learninganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+scikit-learnanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackexchange.com/questions?tab=hotanswertab=votes#tab-top
# https://mathoverflow.net/questions/419634/counterexamples-to-an-analog-of-cannons-conjecture-which-do-not-arise-from-manianswertab=votes#tab-top
# https://worldbuilding.stackexchange.com/questions/227664/what-would-be-the-cost-of-living-in-a-country-where-only-millionaires-and-billioanswertab=votes#tab-top
# https://law.stackexchange.com/questions/79070/how-acceptable-mainstream-marginal-is-the-discussion-about-replacing-the-humananswertab=votes#tab-top
# https://retrocomputing.stackexchange.com/questions/24260/how-was-the-clock-device-used-in-ms-dosanswertab=votes#tab-top
# https://graphicdesign.stackexchange.com/questions/156626/inkscape-how-to-center-node-selection-verticallyanswertab=votes#tab-top
# https://worldbuilding.stackexchange.com/questions/227712/how-do-i-defend-a-walled-citadel-from-a-lizard-armyanswertab=votes#tab-top
# https://politics.stackexchange.com/questions/72349/have-the-leaders-of-un-security-council-permanent-member-states-ever-been-triedanswertab=votes#tab-top
# https://electronics.stackexchange.com/questions/614352/why-use-two-transistors-driving-leds-when-one-would-workanswertab=votes#tab-top
# https://music.stackexchange.com/questions/122193/should-one-transcribe-granular-16th-information-in-sung-melodiesanswertab=votes#tab-top
# https://mathoverflow.net/questions/419588/looking-for-an-interesting-result-on-the-navier-stokes-equationsanswertab=votes#tab-top
# https://philosophy.stackexchange.com/questions/90358/is-g-e-moores-notion-of-goodness-widely-held-and-defended-by-contemporaneous-phanswertab=votes#tab-top
# https://cooking.stackexchange.com/questions/120240/yogurt-tahini-pasteanswertab=votes#tab-top
# https://diy.stackexchange.com/questions/247195/can-an-incoming-optical-fiber-cable-be-wired-internally-in-a-houses-wallsanswertab=votes#tab-top
# https://workplace.stackexchange.com/questions/183871/should-i-apply-for-my-dream-job-even-if-i-expect-to-be-on-maternity-leaveanswertab=votes#tab-top
# https://mathoverflow.net/questions/419646/does-taking-minimum-preserve-density-monotonicityanswertab=votes#tab-top
# https://academia.stackexchange.com/questions/183893/how-do-scientists-get-nominated-for-society-awardanswertab=votes#tab-top
# https://aviation.stackexchange.com/questions/92537/what-button-did-a-pilot-press-that-led-to-them-being-caught-for-falsifying-experanswertab=votes#tab-top
# https://codegolf.stackexchange.com/questions/245901/simulate-the-ripple-effectanswertab=votes#tab-top
# https://english.stackexchange.com/questions/586956/what-is-the-suspension-of-finer-particles-in-the-air-called-when-a-powdery-substanswertab=votes#tab-top
# https://worldbuilding.stackexchange.com/questions/227719/how-would-the-world-governments-define-a-super-personanswertab=votes#tab-top
# https://music.stackexchange.com/questions/122162/how-does-the-chord-progression-g-f-eb-d-workanswertab=votes#tab-top
# https://puzzling.stackexchange.com/questions/115616/solving-two-equations-in-a-creative-wayanswertab=votes#tab-top
# https://or.stackexchange.com/questions/8195/knapsack-how-to-optimize-bonuses-for-each-pair-of-itemsanswertab=votes#tab-top
# https://chemistry.stackexchange.com/questions/164207/why-is-the-boiling-point-of-f2-lower-than-o2answertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.com/feeds/tag?tagnames=python&sort=votesanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.com/questionsanswertab=votes#tab-top
# https://stackoverflow.com/helpanswertab=votes#tab-top
# https://stackoverflow.com/?productsanswertab=votes#tab-top
# https://stackoverflow.co/teamsanswertab=votes#tab-top
# https://stackoverflow.co/advertisinganswertab=votes#tab-top
# https://stackoverflow.co/collectivesanswertab=votes#tab-top
# https://stackoverflow.co/talentanswertab=votes#tab-top
# https://stackoverflow.co/answertab=votes#tab-top
# https://stackoverflow.co/answertab=votes#tab-top
# https://stackoverflow.co/company/pressanswertab=votes#tab-top
# https://stackoverflow.co/company/work-hereanswertab=votes#tab-top
# https://stackoverflow.com/legalanswertab=votes#tab-top
# https://stackoverflow.com/legal/privacy-policyanswertab=votes#tab-top
# https://stackoverflow.com/legal/terms-of-serviceanswertab=votes#tab-top
# https://stackoverflow.co/company/contactanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.com/legal/cookie-policyanswertab=votes#tab-top
# https://stackexchange.comanswertab=votes#tab-top
# https://stackexchange.com/sites#technologyanswertab=votes#tab-top
# https://stackexchange.com/sites#culturerecreationanswertab=votes#tab-top
# https://stackexchange.com/sites#lifeartsanswertab=votes#tab-top
# https://stackexchange.com/sites#scienceanswertab=votes#tab-top
# https://stackexchange.com/sites#professionalanswertab=votes#tab-top
# https://stackexchange.com/sites#businessanswertab=votes#tab-top
# https://api.stackexchange.com/answertab=votes#tab-top
# https://data.stackexchange.com/answertab=votes#tab-top
# https://stackoverflow.blog?blb=1answertab=votes#tab-top
# https://www.facebook.com/officialstackoverflow/answertab=votes#tab-top
# https://twitter.com/stackoverflowanswertab=votes#tab-top
# https://linkedin.com/company/stack-overflowanswertab=votes#tab-top
# https://www.instagram.com/thestackoverflowanswertab=votes#tab-top
# https://stackoverflow.com/help/licensinganswertab=votes#tab-top
# https://stackoverflow.com/legal/cookie-policyanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.co/answertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.com/teamsanswertab=votes#tab-top
# https://stackoverflow.com/questionsanswertab=votes#tab-top
# https://stackoverflow.com/teamsanswertab=votes#tab-top
# https://stackoverflow.co/talentanswertab=votes#tab-top
# https://stackoverflow.co/advertisinganswertab=votes#tab-top
# https://stackoverflow.co/answertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.com/helpanswertab=votes#tab-top
# https://chat.stackoverflow.com/?tab=site&host=stackoverflow.comanswertab=votes#tab-top
# https://meta.stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fpython%3ftab%3dvotes%26page%3d2%26pagesize%3d15answertab=votes#tab-top
# https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fpython%3ftab%3dvotes%26page%3d2%26pagesize%3d15answertab=votes#tab-top
# https://stackexchange.com/sitesanswertab=votes#tab-top
# https://stackoverflow.bloganswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.com/users/login?ssrc=head&returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fpython%3ftab%3dvotes%26page%3d2%26pagesize%3d15answertab=votes#tab-top
# https://stackoverflow.com/users/signup?ssrc=head&returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2ftagged%2fpython%3ftab%3dvotes%26page%3d2%26pagesize%3d15answertab=votes#tab-top
# https://stackoverflow.com/answertab=votes#tab-top
# https://stackoverflow.com/questionsanswertab=votes#tab-top
# https://stackoverflow.com/tagsanswertab=votes#tab-top
# https://stackoverflow.com/usersanswertab=votes#tab-top
# https://stackoverflow.com/jobs/companies?so_medium=stackoverflow&so_source=SiteNavanswertab=votes#tab-top
# https://stackoverflow.comjavascript:void(0)answertab=votes#tab-top
# https://stackoverflow.com/collectivesanswertab=votes#tab-top
# https://stackoverflow.com/teams/create/free?utm_source=so-owned&utm_medium=side-bar&utm_campaign=campaign-38&utm_content=ctaanswertab=votes#tab-top
# https://stackoverflow.co/teamsanswertab=votes#tab-top
# https://stackoverflow.comjavascript:void(0)answertab=votes#tab-top
# https://stackoverflow.com/teams/create/free?utm_source=so-owned&utm_medium=side-bar&utm_campaign=campaign-38&utm_content=ctaanswertab=votes#tab-top
# https://stackoverflow.com/collectivesanswertab=votes#tab-top
# https://stackoverflow.co/teamsanswertab=votes#tab-top
# https://stackoverflow.com/questions/askanswertab=votes#tab-top
# https://stackoverflow.com/tags/python/infoanswertab=votes#tab-top
# https://stackoverflow.com/tags/python/topusersanswertab=votes#tab-top
# https://stackoverflow.com/tags/python/synonymsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=Newestanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=Activeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=Bountiesanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=Unansweredanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=Bountiesanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=Unansweredanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=Frequentanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=Votesanswertab=votes#tab-top
# https://stackoverflow.com/questions/11346283/renaming-column-names-in-pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/replaceanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dataframeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/renameanswertab=votes#tab-top
# https://stackoverflow.com/users/1504276/user1504276answertab=votes#tab-top
# https://stackoverflow.com/users/1504276/user1504276answertab=votes#tab-top
# https://stackoverflow.com/questions/11277432/how-can-i-remove-a-key-from-a-python-dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/unsetanswertab=votes#tab-top
# https://stackoverflow.com/users/692499/tonyanswertab=votes#tab-top
# https://stackoverflow.com/users/692499/tonyanswertab=votes#tab-top
# https://stackoverflow.com/questions/663171/how-do-i-get-a-substring-of-a-string-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/substringanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/questions/2720014/how-to-upgrade-all-python-packages-with-pipanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pipanswertab=votes#tab-top
# https://stackoverflow.com/users/324085/thedjpetersenanswertab=votes#tab-top
# https://stackoverflow.com/users/324085/thedjpetersenanswertab=votes#tab-top
# https://stackoverflow.com/questions/72899/how-do-i-sort-a-list-of-dictionaries-by-a-value-of-the-dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/sortinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/data-structuresanswertab=votes#tab-top
# https://stackoverflow.com/posts/72899/revisionsanswertab=votes#tab-top
# https://stackoverflow.com/users/12398answertab=votes#tab-top
# https://stackoverflow.com/questions/6797984/how-do-i-lowercase-a-string-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/uppercaseanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/lowercaseanswertab=votes#tab-top
# https://stackoverflow.com/users/858922/benjamin-diduranswertab=votes#tab-top
# https://stackoverflow.com/users/858922/benjamin-diduranswertab=votes#tab-top
# https://stackoverflow.com/questions/68645/static-class-variables-and-methods-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/classanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/oopanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/staticanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/class-variablesanswertab=votes#tab-top
# https://stackoverflow.com/users/2246/andrew-walkeranswertab=votes#tab-top
# https://stackoverflow.com/users/2246/andrew-walkeranswertab=votes#tab-top
# https://stackoverflow.com/questions/493386/how-to-print-without-a-newline-or-spaceanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/users/21384/andrea-ambuanswertab=votes#tab-top
# https://stackoverflow.com/users/21384/andrea-ambuanswertab=votes#tab-top
# https://stackoverflow.com/questions/3061/calling-a-function-of-a-module-by-using-its-name-a-stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/objectanswertab=votes#tab-top
# https://stackoverflow.com/users/121/ricreeanswertab=votes#tab-top
# https://stackoverflow.com/users/121/ricreeanswertab=votes#tab-top
# https://stackoverflow.com/questions/1712227/how-do-i-get-the-number-of-elements-in-a-list-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/users/206504/y2kanswertab=votes#tab-top
# https://stackoverflow.com/users/206504/y2kanswertab=votes#tab-top
# https://stackoverflow.com/questions/306400/how-can-i-randomly-select-an-item-from-a-listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/randomanswertab=votes#tab-top
# https://stackoverflow.com/users/4872/rayanswertab=votes#tab-top
# https://stackoverflow.com/users/4872/rayanswertab=votes#tab-top
# https://stackoverflow.com/questions/610883/how-to-know-if-an-object-has-an-attribute-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/attributesanswertab=votes#tab-top
# https://stackoverflow.com/users/20601/lucas-gabriel-s%c3%a1nchezanswertab=votes#tab-top
# https://stackoverflow.com/users/20601/lucas-gabriel-s%c3%a1nchezanswertab=votes#tab-top
# https://stackoverflow.com/questions/990754/how-to-leave-exit-deactivate-a-python-virtualenvanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/virtualenvanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/virtualenvwrapperanswertab=votes#tab-top
# https://stackoverflow.com/users/65326/aprecheanswertab=votes#tab-top
# https://stackoverflow.com/users/65326/aprecheanswertab=votes#tab-top
# https://stackoverflow.com/questions/455612/limiting-floats-to-two-decimal-pointsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/floating-pointanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/roundinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/precisionanswertab=votes#tab-top
# https://stackoverflow.com/questions/101754/is-there-a-way-to-run-python-on-androidanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/androidanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/jythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/aseanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/android-scriptinganswertab=votes#tab-top
# https://stackoverflow.com/users/9951/e-satisanswertab=votes#tab-top
# https://stackoverflow.com/users/9951/e-satisanswertab=votes#tab-top
# https://stackoverflow.com/questions/4383571/importing-files-from-different-folderanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/importerroranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python-importanswertab=votes#tab-top
# https://stackoverflow.com/users/340453/ivananswertab=votes#tab-top
# https://stackoverflow.com/users/340453/ivananswertab=votes#tab-top
# https://stackoverflow.com/questions/9371238/why-is-reading-lines-from-stdin-much-slower-in-c-than-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/c%2b%2banswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/benchmarkinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/iostreamanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/getlineanswertab=votes#tab-top
# https://stackoverflow.com/posts/9371238/revisionsanswertab=votes#tab-top
# https://stackoverflow.com/users/379037answertab=votes#tab-top
# https://stackoverflow.com/questions/5466451/how-can-i-print-literal-curly-brace-characters-in-a-string-and-also-use-formatanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/formatanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/string-formattinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/curly-bracesanswertab=votes#tab-top
# https://stackoverflow.com/users/242670/schittianswertab=votes#tab-top
# https://stackoverflow.com/users/242670/schittianswertab=votes#tab-top
# https://stackoverflow.com/questions/3277503/how-to-read-a-file-line-by-line-into-a-listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/fileanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/readlinesanswertab=votes#tab-top
# https://stackoverflow.com/users/395371/julie-raswickanswertab=votes#tab-top
# https://stackoverflow.com/users/395371/julie-raswickanswertab=votes#tab-top
# https://stackoverflow.com/questions/2225038/determine-the-type-of-an-objectanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/typesanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/typeofanswertab=votes#tab-top
# https://stackoverflow.com/users/101258/justin-ethieranswertab=votes#tab-top
# https://stackoverflow.com/users/101258/justin-ethieranswertab=votes#tab-top
# https://stackoverflow.com/questions/402504/how-to-determine-a-python-variables-typeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/typesanswertab=votes#tab-top
# https://stackoverflow.com/users/46646/user46646answertab=votes#tab-top
# https://stackoverflow.com/users/46646/user46646answertab=votes#tab-top
# https://stackoverflow.com/questions/627435/how-to-remove-an-element-from-a-list-by-indexanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/indexinganswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/questions/493819/why-is-it-string-joinlist-instead-of-list-joinstringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/users/49701/evan-fosmarkanswertab=votes#tab-top
# https://stackoverflow.com/users/49701/evan-fosmarkanswertab=votes#tab-top
# https://stackoverflow.com/questions/2600191/how-can-i-count-the-occurrences-of-a-list-itemanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/countanswertab=votes#tab-top
# https://stackoverflow.com/users/222893/weakishanswertab=votes#tab-top
# https://stackoverflow.com/users/222893/weakishanswertab=votes#tab-top
# https://stackoverflow.com/questions/275018/how-can-i-remove-a-trailing-newlineanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/newlineanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/trailinganswertab=votes#tab-top
# https://stackoverflow.com/questions/5844672/delete-an-element-from-a-dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/delanswertab=votes#tab-top
# https://stackoverflow.com/users/301032/richzillaanswertab=votes#tab-top
# https://stackoverflow.com/users/301032/richzillaanswertab=votes#tab-top
# https://stackoverflow.com/questions/735975/static-methods-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/static-methodsanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/questions/13411544/delete-a-column-from-a-pandas-dataframeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dataframeanswertab=votes#tab-top
# https://stackoverflow.com/users/390388/johnanswertab=votes#tab-top
# https://stackoverflow.com/users/390388/johnanswertab=votes#tab-top
# https://stackoverflow.com/questions/4706499/how-do-you-append-to-a-fileanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/fileanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/appendanswertab=votes#tab-top
# https://stackoverflow.com/questions/9573244/how-to-check-if-the-string-is-emptyanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/comparison-operatorsanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/questions/339007/how-to-pad-zeroes-to-a-stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/zero-paddinganswertab=votes#tab-top
# https://stackoverflow.com/questions/354038/how-do-i-check-if-a-string-is-a-number-floatanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/castinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/floating-pointanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/type-conversionanswertab=votes#tab-top
# https://stackoverflow.com/users/40115/daniel-goldberganswertab=votes#tab-top
# https://stackoverflow.com/users/40115/daniel-goldberganswertab=votes#tab-top
# https://stackoverflow.com/questions/12179271/meaning-of-classmethod-and-staticmethod-for-beginneranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/oopanswertab=votes#tab-top
# ...
# https://stackoverflow.com/users/565083/adriananswertab=votes#tab-top
# https://stackoverflow.com/users/565083/adriananswertab=votes#tab-top
# https://stackoverflow.com/questions/13295735/how-to-replace-nan-values-by-zeroes-in-a-column-of-a-pandas-dataframeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/dataframeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/nananswertab=votes#tab-top
# https://stackoverflow.com/users/1733061/george-thompsonanswertab=votes#tab-top
# https://stackoverflow.com/users/1733061/george-thompsonanswertab=votes#tab-top
# https://stackoverflow.com/questions/145270/calling-c-c-from-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/c%2b%2banswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/canswertab=votes#tab-top
# https://stackoverflow.com/users/9611/shooshanswertab=votes#tab-top
# https://stackoverflow.com/users/9611/shooshanswertab=votes#tab-top
# https://stackoverflow.com/questions/432112/is-there-a-numpy-function-to-return-the-first-index-of-something-in-an-arrayanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/arraysanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/numpyanswertab=votes#tab-top
# https://stackoverflow.com/users/41718/nopeanswertab=votes#tab-top
# https://stackoverflow.com/users/41718/nopeanswertab=votes#tab-top
# https://stackoverflow.com/questions/12934190/is-there-a-short-contains-function-for-listsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/searchanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/collectionsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/containsanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/users/51816/joan-vengeanswertab=votes#tab-top
# https://stackoverflow.com/questions/17130975/python-vs-cpythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/cpythonanswertab=votes#tab-top
# https://stackoverflow.com/users/2425215/k-dawganswertab=votes#tab-top
# https://stackoverflow.com/users/2425215/k-dawganswertab=votes#tab-top
# https://stackoverflow.com/questions/9780717/bash-pip-command-not-foundanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/macosanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pipanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python-2.6answertab=votes#tab-top
# https://stackoverflow.com/users/193601/trindazanswertab=votes#tab-top
# https://stackoverflow.com/users/193601/trindazanswertab=votes#tab-top
# https://stackoverflow.com/questions/3777861/setting-y-axis-limit-in-matplotlibanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/matplotlibanswertab=votes#tab-top
# https://stackoverflow.com/users/316357/curious2learnanswertab=votes#tab-top
# https://stackoverflow.com/users/316357/curious2learnanswertab=votes#tab-top
# https://stackoverflow.com/questions/452104/is-it-worth-using-pythons-re-compileanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/regexanswertab=votes#tab-top
# https://stackoverflow.com/users/42974/matanswertab=votes#tab-top
# https://stackoverflow.com/users/42974/matanswertab=votes#tab-top
# https://stackoverflow.com/questions/375427/a-non-blocking-read-on-a-subprocess-pipe-in-pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/ioanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/subprocessanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/nonblockinganswertab=votes#tab-top
# https://stackoverflow.com/users/5861/mathieu-pag%c3%a9answertab=votes#tab-top
# https://stackoverflow.com/users/5861/mathieu-pag%c3%a9answertab=votes#tab-top
# https://stackoverflow.com/questions/19339/transpose-unzip-function-inverse-of-zipanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/matrixanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/transposeanswertab=votes#tab-top
# https://stackoverflow.com/users/680/cristiananswertab=votes#tab-top
# https://stackoverflow.com/users/680/cristiananswertab=votes#tab-top
# https://stackoverflow.com/questions/1546226/is-there-a-simple-way-to-remove-multiple-spaces-in-a-stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/regexanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/stringanswertab=votes#tab-top
# https://stackoverflow.com/users/179736/timexanswertab=votes#tab-top
# https://stackoverflow.com/users/179736/timexanswertab=votes#tab-top
# https://stackoverflow.com/questions/2642613/what-is-related-name-used-foranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/pythonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/djangoanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/foreign-keysanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/many-to-manyanswertab=votes#tab-top
# https://stackoverflow.com/users/234322/zjm1126answertab=votes#tab-top
# https://stackoverflow.com/users/234322/zjm1126answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=10answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=1answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=9answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=10answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=12answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=13answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=38469answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python?tab=votes&page=12answertab=votes#tab-top
# https://stackoverflow.blog/2022/04/04/comparing-go-vs-c-in-embedded-applications/answertab=votes#tab-top
# https://stackoverflow.blog/2022/03/31/time-to-get-on-trend-filters/answertab=votes#tab-top
# https://meta.stackoverflow.com/questions/416964/the-future-of-our-jobs-ad-slotsanswertab=votes#tab-top
# https://meta.stackoverflow.com/questions/416735/ask-wizard-for-new-users-feature-test-is-now-liveanswertab=votes#tab-top
# https://meta.stackoverflow.com/questions/416887/calling-up-moderators-from-the-2021-election-welcome-dharman-ryan-manswertab=votes#tab-top
# https://meta.stackoverflow.com/questions/416851/staging-ground-workflow-question-details-actionsanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+pandasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+python-3.xanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+djangoanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+numpyanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+dataframeanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+python-2.7answertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+listanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+matplotlibanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+tensorflowanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+dictionaryanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+tkinteranswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+flaskanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+regexanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+seleniumanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+arraysanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+csvanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+jsonanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+stringanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+htmlanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+beautifulsoupanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+kerasanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+opencvanswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+web-scrapinganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+machine-learninganswertab=votes#tab-top
# https://stackoverflow.com/questions/tagged/python+scikit-learnanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackexchange.com/questions?tab=hotanswertab=votes#tab-top
# https://academia.stackexchange.com/questions/183876/declining-invitation-to-review-because-authors-are-hostileanswertab=votes#tab-top
# https://space.stackexchange.com/questions/58765/how-does-the-jwst-change-focus-when-it-goes-from-looking-at-a-near-subject-to-loanswertab=votes#tab-top
# https://workplace.stackexchange.com/questions/183870/what-categories-of-projects-outside-of-embedded-are-there-for-a-c-developer-noanswertab=votes#tab-top
# https://linguistics.stackexchange.com/questions/44216/what-do-titles-and-beijing-stand-foranswertab=votes#tab-top
# https://chess.stackexchange.com/questions/39602/what-fundamental-mistakes-were-made-in-my-game-that-slowly-turned-in-to-a-lossanswertab=votes#tab-top
# https://mathoverflow.net/questions/419588/looking-for-an-interesting-result-on-the-navier-stokes-equationsanswertab=votes#tab-top
# https://workplace.stackexchange.com/questions/183871/should-i-apply-for-my-dream-job-even-if-i-expect-to-be-on-maternity-leaveanswertab=votes#tab-top
# https://blender.stackexchange.com/questions/259590/why-is-my-cylinder-not-unwrapping-squareanswertab=votes#tab-top
# https://travel.stackexchange.com/questions/172914/can-i-take-my-granddaughter-to-her-train-platform-when-she-travels-to-yorkanswertab=votes#tab-top
# https://superuser.com/questions/1714319/system-is-ready-to-into-shipping-mode-after-changing-settings-in-biosanswertab=votes#tab-top
# https://astronomy.stackexchange.com/questions/48998/the-moon-in-the-first-phase-visible-in-the-sky-is-tiltedanswertab=votes#tab-top
# https://academia.stackexchange.com/questions/183842/where-can-i-publish-a-parody-but-not-hoax-paper-with-a-serious-messageanswertab=votes#tab-top
# https://scifi.stackexchange.com/questions/261928/which-sci-fi-work-first-showed-sentient-plasticanswertab=votes#tab-top
# https://unix.stackexchange.com/questions/697944/get-result-from-awk-using-two-delimiters-in-a-single-commandanswertab=votes#tab-top
# https://german.stackexchange.com/questions/70185/when-showing-interest-about-people-how-is-the-gender-inferredanswertab=votes#tab-top
# https://literature.stackexchange.com/questions/22215/what-does-the-term-one-heat-down-in-dickenss-little-dorrit-meananswertab=votes#tab-top
# https://tex.stackexchange.com/questions/639662/collecting-the-content-between-two-macros-and-pass-it-to-the-thirdanswertab=votes#tab-top
# https://cooking.stackexchange.com/questions/120240/yogurt-tahini-pasteanswertab=votes#tab-top
# https://retrocomputing.stackexchange.com/questions/24260/how-was-the-clock-device-used-in-ms-dosanswertab=votes#tab-top
# https://scifi.stackexchange.com/questions/261916/book-about-a-boy-whose-tribe-is-separated-from-another-tribe-by-a-swamp-and-taboanswertab=votes#tab-top
# https://proofassistants.stackexchange.com/questions/1239/replacing-strict-positivity-with-monotonicity-on-propositionsanswertab=votes#tab-top
# https://politics.stackexchange.com/questions/72321/besides-the-philippines-do-any-countries-have-bilingual-presidential-debates-reqanswertab=votes#tab-top
# https://money.stackexchange.com/questions/150203/does-the-term-ordinary-dividends-include-qualified-dividendsanswertab=votes#tab-top
# https://german.stackexchange.com/questions/70178/why-is-this-noun-dativeanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.com/feeds/tag?tagnames=python&sort=votesanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.com/questionsanswertab=votes#tab-top
# https://stackoverflow.com/helpanswertab=votes#tab-top
# https://stackoverflow.com/?productsanswertab=votes#tab-top
# https://stackoverflow.co/teamsanswertab=votes#tab-top
# https://stackoverflow.co/advertisinganswertab=votes#tab-top
# https://stackoverflow.co/collectivesanswertab=votes#tab-top
# https://stackoverflow.co/talentanswertab=votes#tab-top
# https://stackoverflow.co/answertab=votes#tab-top
# https://stackoverflow.co/answertab=votes#tab-top
# https://stackoverflow.co/company/pressanswertab=votes#tab-top
# https://stackoverflow.co/company/work-hereanswertab=votes#tab-top
# https://stackoverflow.com/legalanswertab=votes#tab-top
# https://stackoverflow.com/legal/privacy-policyanswertab=votes#tab-top
# https://stackoverflow.com/legal/terms-of-serviceanswertab=votes#tab-top
# https://stackoverflow.co/company/contactanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.com/legal/cookie-policyanswertab=votes#tab-top
# https://stackexchange.comanswertab=votes#tab-top
# https://stackexchange.com/sites#technologyanswertab=votes#tab-top
# https://stackexchange.com/sites#culturerecreationanswertab=votes#tab-top
# https://stackexchange.com/sites#lifeartsanswertab=votes#tab-top
# https://stackexchange.com/sites#scienceanswertab=votes#tab-top
# https://stackexchange.com/sites#professionalanswertab=votes#tab-top
# https://stackexchange.com/sites#businessanswertab=votes#tab-top
# https://api.stackexchange.com/answertab=votes#tab-top
# https://data.stackexchange.com/answertab=votes#tab-top
# https://stackoverflow.blog?blb=1answertab=votes#tab-top
# https://www.facebook.com/officialstackoverflow/answertab=votes#tab-top
# https://twitter.com/stackoverflowanswertab=votes#tab-top
# https://linkedin.com/company/stack-overflowanswertab=votes#tab-top
# https://www.instagram.com/thestackoverflowanswertab=votes#tab-top
# https://stackoverflow.com/help/licensinganswertab=votes#tab-top
# https://stackoverflow.com/legal/cookie-policyanswertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.co/answertab=votes#tab-top
# https://stackoverflow.com#answertab=votes#tab-top
# https://stackoverflow.com/teamsanswertab=votes#tab-top
# https://stackoverflow.com/questionsanswertab=votes#tab-top
# https://stackoverflow.com/teamsanswertab=votes#tab-top
# https://stackoverflow.co/talentanswertab=votes#tab-top
# https://stackoverflow.co/advertisinganswertab=votes#tab-top
# https://stackoverflow.co/answertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.comanswertab=votes#tab-top
# https://stackoverflow.com/helpanswertab=votes#tab-top
# https://chat.stackoverflow.com/?tab=site&host=stackoverflow.comanswertab=votes#tab-top

# %%
print(Questions)
# Out:
# []
