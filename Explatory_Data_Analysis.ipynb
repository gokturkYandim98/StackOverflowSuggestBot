# %%
#Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reading the clean data
df = pd.read_csv('/content/drive/MyDrive/data_preprocessed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298024 entries, 0 to 298023
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   tags                298024 non-null  object
#  1   is_answered         298024 non-null  bool
#  2   view_count          298024 non-null  int64
#  3   answer_count        298024 non-null  int64
#  4   score               298024 non-null  int64
#  5   last_activity_date  298024 non-null  object
#  6   creation_date       298024 non-null  object
#  7   question_id         298024 non-null  int64
#  8   link                298024 non-null  object
#  9   title               298017 non-null  object
#  10  accepted_answer_id  222905 non-null  float64
# dtypes: bool(1), float64(1), int64(4), object(5)
# memory usage: 23.0+ MB

# %%
df.columns
# Out:
# Index(['tags', 'is_answered', 'view_count', 'answer_count', 'score',
#        'last_activity_date', 'creation_date', 'question_id', 'link', 'title',
#        'accepted_answer_id'],
#       dtype='object')

# %%
df.shape
# Out:
# (298024, 11)

# %%
df.head()
# Out:
#                                                 tags  is_answered  view_count  \
# 0  ['python', 'excel', 'tkinter', 'row', 'openpyxl']         True          46
# 1                            ['python', 'try-catch']         True          47
# 2                           ['python', 'matplotlib']         True        9267
# 3         ['python', 'datetime', 'date', 'timezone']         True      469727
# 4          ['python', 'modbus', 'rs485', 'pymodbus']         True         650
#
#    answer_count  score last_activity_date creation_date  question_id  \
# 0             1      2         2022-04-27    2022-04-25     72005204
# 1             3      2         2022-04-27    2022-04-26     72020038
# 2             3      2         2022-04-27    2019-06-21     56704699
# 3            19    421         2022-04-27    2010-12-25      4530069
# 4             2      2         2022-04-27    2020-06-17     62418945
#
#                                                 link  \
# 0  https://stackoverflow.com/questions/72005204/c...
# 1  https://stackoverflow.com/questions/72020038/r...
# 2  https://stackoverflow.com/questions/56704699/w...
# 3  https://stackoverflow.com/questions/4530069/ho...
# 4  https://stackoverflow.com/questions/62418945/m...
#
#                                             title  accepted_answer_id
# 0              changing row excel file row filled          72005405.0
# 1                 raise string variable exception                 NaN
# 2    matplotlib plot kind bar plot different plot          56706020.0
# 3  get value datetime today python timezone aware           4530166.0
# 4                  modbus python schneider pm5300          62424060.0

# %%
df.tail()
# Out:
#                                                      tags  is_answered  \
# 298019                  ['python', 'pandas', 'dataframe']         True
# 298020  ['python', 'python-3.x', 'windows', 'encryption']         True
# 298021               ['python', 'django', 'django-admin']         True
# 298022            ['python', 'image', 'image-processing']         True
# 298023                  ['python', 'pandas', 'dataframe']         True
#
#         view_count  answer_count  score last_activity_date creation_date  \
# 298019         669             1      1         2019-02-06    2019-02-06
# 298020         192             2      2         2019-02-06    2019-02-06
# 298021         376             1      1         2019-02-06    2019-02-06
# 298022         358             1      3         2019-02-06    2019-02-05
# 298023         141             2      4         2019-02-06    2019-02-06
#
#         question_id                                               link  \
# 298019     54548553  https://stackoverflow.com/questions/54548553/c...
# 298020     54544013  https://stackoverflow.com/questions/54544013/s...
# 298021     54547276  https://stackoverflow.com/questions/54547276/d...
# 298022     54535151  https://stackoverflow.com/questions/54535151/c...
# 298023     54548236  https://stackoverflow.com/questions/54548236/h...
#
#                                                     title  accepted_answer_id
# 298019                 convert list list dataframe python          54548614.0
# 298020       simple way encrypt strings polish characters                 NaN
# 298021            django staff users manage users created                 NaN
# 298022                   create animated gif static image          54535895.0
# 298023  unique keyword simplification sort alphabetica...          54548284.0

# %%
df.describe()
# Out:
#          view_count   answer_count          score   question_id  \
# count  2.980240e+05  298024.000000  298024.000000  2.980240e+05
# mean   7.876268e+03       1.921332       6.188478  5.853558e+07
# std    7.361638e+04       1.927116      69.824787  1.449131e+07
# min    8.000000e+00       0.000000     -42.000000  5.020000e+02
# 25%    5.500000e+01       1.000000       0.000000  5.639906e+07
# 50%    1.580000e+02       1.000000       1.000000  6.232490e+07
# 75%    9.710000e+02       2.000000       2.000000  6.768951e+07
# max    6.680861e+06      70.000000   11982.000000  7.202173e+07
#
#        accepted_answer_id
# count        2.229050e+05
# mean         5.882629e+07
# std          1.453001e+07
# min          1.857000e+03
# 25%          5.675637e+07
# 50%          6.261497e+07
# 75%          6.785520e+07
# max          7.202165e+07

# %%
df.isnull()
# Out:
#          tags  is_answered  view_count  answer_count  score  \
# 0       False        False       False         False  False
# 1       False        False       False         False  False
# 2       False        False       False         False  False
# 3       False        False       False         False  False
# 4       False        False       False         False  False
# ...       ...          ...         ...           ...    ...
# 298019  False        False       False         False  False
# 298020  False        False       False         False  False
# 298021  False        False       False         False  False
# 298022  False        False       False         False  False
# 298023  False        False       False         False  False
#
#         last_activity_date  creation_date  question_id   link  title  \
# 0                    False          False        False  False  False
# 1                    False          False        False  False  False
# 2                    False          False        False  False  False
# 3                    False          False        False  False  False
# 4                    False          False        False  False  False
# ...                    ...            ...          ...    ...    ...
# 298019               False          False        False  False  False
# 298020               False          False        False  False  False
# 298021               False          False        False  False  False
# 298022               False          False        False  False  False
# 298023               False          False        False  False  False
#
#         accepted_answer_id
# 0                    False
# 1                     True
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 298019               False
# 298020                True
# 298021                True
# 298022               False
# 298023               False
#
# [298024 rows x 11 columns]

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                                      tags  is_answered  \
# 1                                 ['python', 'try-catch']         True
# 5                                              ['python']         True
# 7         ['python', 'terminal', 'output', 'ansi-colors']         True
# 9            ['python', 'anaconda', 'conda', 'geopandas']         True
# 11      ['python', 'amazon-web-services', 'single-sign...         True
# ...                                                   ...          ...
# 298006                       ['python', 'xpath', 'scapy']         True
# 298010  ['python', 'xml', 'python-2.7', 'odoo', 'odoo-8']         True
# 298016                 ['python', 'pygame', 'inequality']         True
# 298020  ['python', 'python-3.x', 'windows', 'encryption']         True
# 298021               ['python', 'django', 'django-admin']         True
#
#         view_count  answer_count  score last_activity_date creation_date  \
# 1               47             3      2         2022-04-27    2022-04-26
# 5               34             1      1         2022-04-27    2022-04-27
# 7          1907747            56   2785         2022-04-27    2008-11-13
# 9           100417            12     80         2022-04-27    2019-02-17
# 11           10861             5     11         2022-04-27    2020-06-10
# ...            ...           ...    ...                ...           ...
# 298006          78             1      1         2019-02-06    2019-02-01
# 298010        2196             1      1         2019-02-06    2015-09-04
# 298016          51             2      1         2019-02-06    2019-02-06
# 298020         192             2      2         2019-02-06    2019-02-06
# 298021         376             1      1         2019-02-06    2019-02-06
#
#         question_id                                               link  \
# 1          72020038  https://stackoverflow.com/questions/72020038/r...
# 5          72021670  https://stackoverflow.com/questions/72021670/i...
# 7            287871  https://stackoverflow.com/questions/287871/how...
# 9          54734667  https://stackoverflow.com/questions/54734667/e...
# 11         62311866  https://stackoverflow.com/questions/62311866/h...
# ...             ...                                                ...
# 298006     54486534  https://stackoverflow.com/questions/54486534/e...
# 298010     32404571  https://stackoverflow.com/questions/32404571/h...
# 298016     54545550  https://stackoverflow.com/questions/54545550/h...
# 298020     54544013  https://stackoverflow.com/questions/54544013/s...
# 298021     54547276  https://stackoverflow.com/questions/54547276/d...
#
#                                                     title  accepted_answer_id
# 1                         raise string variable exception                 NaN
# 5                               better way compare values                 NaN
# 7                      print colored text terminal python                 NaN
# 9       error installing geopandas gdal api version mu...                 NaN
# 11      use aws python sdk connecting via sso credentials                 NaN
# ...                                                   ...                 ...
# 298006                 escaping quote xpath python script                 NaN
# 298010         add page notebook dynamically odoo openerp                 NaN
# 298016  set inequality check consumption basically col...                 NaN
# 298020       simple way encrypt strings polish characters                 NaN
# 298021            django staff users manage users created                 NaN
#
# [75122 rows x 11 columns]

# %%
df.isnull().sum(axis=0)
# Out:
# tags                      0
# is_answered               0
# view_count                0
# answer_count              0
# score                     0
# last_activity_date        0
# creation_date             0
# question_id               0
# link                      0
# title                     7
# accepted_answer_id    75119
# dtype: int64

# %% [markdown]
# # Some Visualizations

# %%
#Creating heatmap to find out missing columns and scale of missing data
sns.heatmap(df.isna())

# %%
df['view_count'].fillna(0, inplace=True)

# %%
df['title'].fillna(0, inplace=True)

# %%
df['accepted_answer_id'].fillna(0, inplace=True)

# %%
df.isnull().sum(axis=0)
# Out:
# tags                  0
# is_answered           0
# view_count            0
# answer_count          0
# score                 0
# last_activity_date    0
# creation_date         0
# question_id           0
# link                  0
# title                 0
# accepted_answer_id    0
# dtype: int64

# %%
df[df.duplicated(['question_id'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [tags, is_answered, view_count, answer_count, score, last_activity_date, creation_date, question_id, link, title, accepted_answer_id]
# Index: []

# %%
#Let's analyze correlation
sns.heatmap(df.corr(),cmap='coolwarm')
plt.title('df.corr()')
# Out:
# Text(0.5, 1.0, 'df.corr()')

# %%
#Analyze Answer Count
sns.countplot(x='answer_count',data=df)

# %% [markdown]
# # Exploratory Analysis on Text Columns

# %%
df['title'].describe()
# Out:
# count                                     298017
# unique                                    297399
# top       valueerror invalid literal int base 10
# freq                                           8
# Name: title, dtype: object

# %%
print(df['tags'].unique())
# Out:
# ["['python', 'excel', 'tkinter', 'row', 'openpyxl']"
#  "['python', 'try-catch']" "['python', 'matplotlib']" ...
#  "['python', 'pygame', 'inequality']"
#  "['python', 'django', 'multithreading', 'decorator', 'python-multithreading']"
#  "['python', 'python-3.x', 'windows', 'encryption']"]

# %%
print(df['tags'].value_counts())
# Out:
# ['python']                                                        18536
# ['python', 'pandas']                                              11224
# ['python', 'pandas', 'dataframe']                                  6283
# ['python', 'python-3.x']                                           5765
# ['python', 'django']                                               3644
#                                                                   ...
# ['python', 'pandas', 'dataframe', 'merge', 'aggregate']               1
# ['python', 'assert', 'assertion', 'raise']                            1
# ['python', 'django', 'httpcookie']                                    1
# ['python', 'django', 'database', 'sqlite', 'django-templates']        1
# ['python', 'python-3.x', 'windows', 'encryption']                     1
# Name: tags, Length: 118208, dtype: int64

# %%
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

#mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1 


stopwords = set(STOPWORDS)
#data = pd.read_csv("../input/most_backed.csv")

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(df['title']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
#fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f2fa449fb90>

# %%
#mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=200             #72 
mpl.rcParams['figure.subplot.bottom']=.1 


stopwords = set(STOPWORDS)
#data = pd.read_csv("../input/most_backed.csv")

wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(df['tags']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
#fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f2fa445b4d0>
